# %% [markdown]
# # The weather from Minneapolis weather stations, August 2019 is found below
# The data was pulled from https://www.ncdc.noaa.gov/
#
# The column keys are
#
# DAPR - Number of days included in the multiday precipitation total (MDPR)
#
# SNOW - Snowfall
#
# WT03 - Thunder
#
# WT04 - Ice pellets, sleet, snow pellets, or small hail
#
# PRCP - Precipitation
#
# WT05 - Hail (may include small hail)
#
# TOBS - Temperature at the time of observation
#
# WT06 - Glaze or rime
#
# WT08 - Smoke or haze
#
# SNWD - Snow depth
#
# WT09 - Blowing or drifting snow
#
# WT01 - Fog, ice fog, or freezing fog (may include heavy fog)
#
# TMAX - Maximum temperature
#
# WT02 - Heavy fog or heaving freezing fog (not always distinguished from fog)
#
# TAVG - Average Temperature.
#
# TMIN - Minimum temperature
#
# MDPR - Multiday precipitation total (use with DAPR and DWPR, if available)

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


# import the data set, August 2019 NiceRide data
df_bike = pd.read_csv('/Users/no50free/GitHub/NiceRide/201908-niceride-tripdata.csv')

# %%
df=pd.read_csv('/Users/no50free/GitHub/biking/2243595.csv')

# %%
df.loc[df['NAME']=='MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US']
# Out:
#          STATION                                               NAME  \
# 93   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 94   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 95   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 96   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 97   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 98   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 99   USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 100  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 101  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 102  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 103  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 104  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# 105  USW00014922  MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US
# ...

# %%
days=np.linspace(1,31,31)
temps=df['TMAX'][93:124].tolist()
rain=df['PRCP'][0:31].tolist()
rain_scaled = [x*20 for x in rain]

# Made dates datetime format
df_bike['start_time'] = pd.to_datetime(df_bike['start_time'])
riders=df_bike.groupby(df_bike['start_time'].dt.day)['usertype'].count()

# %%
fig, ax = plt.subplots()

plt.plot(days,temps,'r')
plt.plot(days,riders/40,'b')
plt.plot(days,rain_scaled,'k')
plt.grid(color='g',axis='x')
ax.set_xticks([4, 11, 18, 25], minor=False)
plt.xlabel('days of August')
plt.legend(['Temp (F)','Users (scaled)','Rain (scaled)'],loc=(.01,.2))

plt.savefig('weather.png')

# %%
rain=df['PRCP'][0:31].tolist()

# %%
df['PRCP'][0:31]
# Out:
# 0     0.00
# 1     0.00
# 2     0.00
# 3     0.11
# 4     0.00
# 5     0.12
# 6     0.00
# 7     0.00
# 8     0.00
# 9     0.00
# 10    0.81
# 11    0.00
# 12    0.00
# 13    0.63
# 14    0.00
# 15    0.58
# 16    0.00
# 17    3.10
# 18    0.00
# 19    0.00
# 20    0.68
# 21    0.00
# 22    0.00
# 23    0.00
# 24    0.00
# 25    0.04
# 26    0.76
# 27    0.04
# 28    0.01
# 29    0.00
# 30    0.00
# Name: PRCP, dtype: float64

# %%
df[0:31]
# Out:
#         STATION                              NAME        DATE  DAPR  MDPR  \
# 0   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-01   NaN   NaN
# 1   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-02   NaN   NaN
# 2   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-03   NaN   NaN
# 3   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-04   NaN   NaN
# 4   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-05   NaN   NaN
# 5   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-06   NaN   NaN
# 6   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-07   NaN   NaN
# 7   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-08   NaN   NaN
# 8   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-09   NaN   NaN
# 9   USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-10   NaN   NaN
# 10  USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-11   NaN   NaN
# 11  USC00218450  UNIVERSITY OF MN ST. PAUL, MN US  2019-08-12   NaN   NaN
# ...

# %%
rain
# Out:
# [0.0,
#  0.0,
#  0.0,
#  0.11,
#  0.0,
#  0.12,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.81,
#  0.0,
#  0.0,
#  0.63,
#  0.0,
#  0.58,
#  0.0,
#  3.1,
#  0.0,
#  0.0,
#  0.68,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.04,
#  0.76,
#  0.04,
#  0.01,
#  0.0,
#  0.0]
